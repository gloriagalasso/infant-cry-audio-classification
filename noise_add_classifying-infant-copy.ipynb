# %% [markdown]
# > **Citing: Grayson, S., & Zhu, W. (Year). "Baby Cry Classifications Using Deep Learning." AIRCC Publishing Corporation, Volume 11 Number 14**
#
#
# Also the notebook messages are generated by ChatGPT and verified by me to ensure proper idea is delivered to the reader

# %%
import os
base_path = "/Users/gloria/Documents/uniproject/infant_cry/data/donateacry_corpus"
classes = ['belly_pain', 'burping', 'discomfort', 'hungry', 'tired']

for cls in classes:
    folder = os.path.join(base_path, cls)
    audio_files = [f for f in os.listdir(folder) if f.endswith('.wav')]
    print(f"{cls}: {len(audio_files)} files")
# Out:
# belly_pain: 382 files
# burping: 382 files
# discomfort: 382 files
# hungry: 382 files
# tired: 382 files

# %%
# !pip install librosa==0.9.2
# Out:
# Requirement already satisfied: librosa==0.9.2 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (0.9.2)
# Requirement already satisfied: audioread>=2.1.9 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from librosa==0.9.2) (3.0.1)
# Requirement already satisfied: numpy>=1.17.0 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from librosa==0.9.2) (2.1.3)
# Requirement already satisfied: scipy>=1.2.0 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from librosa==0.9.2) (1.15.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from librosa==0.9.2) (1.7.0)
# Requirement already satisfied: joblib>=0.14 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from librosa==0.9.2) (1.5.1)
# Requirement already satisfied: decorator>=4.0.10 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from librosa==0.9.2) (5.2.1)
# Requirement already satisfied: resampy>=0.2.2 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from librosa==0.9.2) (0.4.3)
# Requirement already satisfied: numba>=0.45.1 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from librosa==0.9.2) (0.61.2)
# Requirement already satisfied: soundfile>=0.10.2 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from librosa==0.9.2) (0.13.1)
# Requirement already satisfied: pooch>=1.0 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from librosa==0.9.2) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from librosa==0.9.2) (25.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from numba>=0.45.1->librosa==0.9.2) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from pooch>=1.0->librosa==0.9.2) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from pooch>=1.0->librosa==0.9.2) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (2025.4.26)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from scikit-learn>=0.19.1->librosa==0.9.2) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from soundfile>=0.10.2->librosa==0.9.2) (1.17.1)
# Requirement already satisfied: pycparser in /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.2) (2.22)

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">⬇️ Import Libraries</span>

# %%
import numpy as np
import pandas as pd
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
import tensorflow
from tensorflow.keras.layers import LSTM, Dense
import soundfile as sf # to add noise
import random
import scipy.signal
# Out:
# /Users/gloria/Library/Caches/pypoetry/virtualenvs/infant-cry-eRETXQ1W-py3.11/lib/python3.11/site-packages/librosa/util/files.py:10: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#     &nbsp;<b>Augment imbalanced classes.</b><br>
#     <br>
#     &nbsp;<b>Hungry is the majority class. The other classes need to reach the number of hungry audio files.</b><br>
# </div>

# %%
def add_noise(data, noise_factor=0.005):
    noise = np.random.randn(len(data))
    augmented_data = data + noise_factor * noise
    return np.clip(augmented_data, -1.0, 1.0).astype(data.dtype)

def change_speed(data, speed_factor=1.25):
    try:
        return librosa.effects.time_stretch(data, speed_factor)
    except Exception:
        return data  # fallback to original if speed stretch fails

def bandpass_filter(data, sr, lowcut=300.0, highcut=3000.0):
    nyquist = 0.5 * sr
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = scipy.signal.butter(4, [low, high], btype='band')
    filtered_data = scipy.signal.lfilter(b, a, data)
    return np.clip(filtered_data, -1.0, 1.0)

for cls in classes:
    folder = os.path.join(base_path, cls)
    audio_files = [f for f in os.listdir(folder) if f.endswith('.wav')]
    current_count = len(audio_files)
    needed = target_count - current_count

    if needed > 0:
        for i in range(needed):
            file_to_augment = random.choice(audio_files)
            file_path = os.path.join(folder, file_to_augment)
            data, sr = librosa.load(file_path, sr=None)

            # Choose augmentation type randomly
            aug_type = random.choice(['noise', 'speed', 'bandpass'])

            if aug_type == 'noise':
                augmented = add_noise(data)
                suffix = 'noisy'
            elif aug_type == 'speed':
                augmented = change_speed(data, speed_factor=random.uniform(1.05, 1.2))
                suffix = 'speed'
            else:  # bandpass
                augmented = bandpass_filter(data, sr, lowcut=300, highcut=3000)
                suffix = 'bandpass'

            new_filename = f"{os.path.splitext(file_to_augment)[0]}_{suffix}_{i}.wav"
            new_path = os.path.join(folder, new_filename)
            sf.write(new_path, augmented, sr)

        print(f"Added {needed} augmented files to {cls}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 20
#      17     filtered_data = scipy.signal.lfilter(b, a, data)
#      18     return np.clip(filtered_data, -1.0, 1.0)
# ---> 20 for cls in classes:
#      21     folder = os.path.join(base_path, cls)
#      22     audio_files = [f for f in os.listdir(folder) if f.endswith('.wav')]
#
# NameError: name 'classes' is not defined

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#     &nbsp;<b>Check how many audios per class.</b><br>
# </div>

# %%
base_path = "/Users/gloria/Documents/uniproject/infant_cry/data/donateacry_corpus"
classes = ['belly_pain', 'burping', 'discomfort', 'hungry', 'tired']

for cls in classes:
    folder = os.path.join(base_path, cls)
    audio_files = os.listdir(folder)
    print(f"{cls}: {len(audio_files)} file")
# Out:
# belly_pain: 382 file
# burping: 382 file
# discomfort: 382 file
# hungry: 382 file
# tired: 382 file

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#     &nbsp;<b>The function create_spectrogram takes an input audio file path and generates a spectrogram image, saving it to the specified image file path. It utilizes the librosa library to load the audio, compute its mel spectrogram, and convert the power spectrogram to a decibel scale for better visualization.</b><br>
#     <br>
#     &nbsp;<b>The create_pngs_from_wavs function automates the process for multiple audio files within a given directory. It converts all .wav files in the specified input directory into spectrogram images, saving the resulting images to the designated output directory. This function makes use of the create_spectrogram function internally to generate the spectrogram images.</b><br>
# </div>

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">📊 Data Processing and Training set generation</span>

# %%
def create_spectrogram(audio_file, image_file):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1)

    y, sr = librosa.load(audio_file)
    ms = librosa.feature.melspectrogram(y, sr=sr)
    log_ms = librosa.power_to_db(ms, ref=np.max)
    librosa.display.specshow(log_ms, sr=sr)

    fig.savefig(image_file)
    plt.close(fig)

def create_pngs_from_wavs(input_path, output_path):
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    dir = os.listdir(input_path)

    for i, file in enumerate(dir):
        input_file = os.path.join(input_path, file)
        output_file = os.path.join(output_path, file.replace('.wav', '.png'))
        create_spectrogram(input_file, output_file)

# %%
create_pngs_from_wavs('data/donateacry_corpus/belly_pain', 'data/working/belly_pain')
create_pngs_from_wavs('data/donateacry_corpus/burping', 'data/working/burping')
create_pngs_from_wavs('data/donateacry_corpus/discomfort', 'data/working/discomfort')
create_pngs_from_wavs('data/donateacry_corpus/hungry', 'data/working/hungry')
create_pngs_from_wavs('data/donateacry_corpus/tired', 'data/working/tired')

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#     &nbsp;<b>Loading the images from the path</b><br>
# </div>

# %%
x = []
y = []

from keras.preprocessing import image

def load_images_from_path(path, label):
    #taking 20 spectrogram each for every label
    images = []
    labels = []

    for file in os.listdir(path):
        images.append(image.img_to_array(image.load_img(os.path.join(path, file), target_size=(224, 224, 3))))
        labels.append((label))

    return images, labels

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#     &nbsp;<b>The function takes in source patterns and their corresponding destination paths as input. If the destination directory doesn't exist, it creates the directory and proceeds with moving the files. It utilizes the glob module to identify the files based on the specified patterns and shutil for the file movement.</b><br>
#     <br>
#     &nbsp;<b>With this we create the training dataset and leave a file for each type for testing.</b><br>
# </div>

# %%
import glob
import shutil

def move_files(source_pattern, destination_path):
    if not os.path.exists(destination_path):
        os.makedirs(destination_path)
        print(f"Directory '{destination_path}' created successfully.")
    else:
        print(f"Directory '{destination_path}' already exists.")

    files_to_move = glob.glob(source_pattern)
    for file_path in files_to_move[:-1]:
        shutil.move(file_path, destination_path)

# Define your directories and source patterns
directories = {
    'data/working/belly_pain_train/': 'data/working/belly_pain/*.png',
    'data/working/burping_train/': 'data/working/burping/*.png',
    'data/working/discomfort_train/': 'data/working/discomfort/*.png',
    'data/working/hungry_train/': 'data/working/hungry/*.png',
    'data/working/tired_train/': 'data/working/tired/*.png'
}

# Loop through the directories and move the files
for directory, source_pattern in directories.items():
    move_files(source_pattern, directory)
# Out:
# Directory 'data/working/belly_pain_train/' created successfully.
# Directory 'data/working/burping_train/' created successfully.
# Directory 'data/working/discomfort_train/' created successfully.
# Directory 'data/working/hungry_train/' created successfully.
# Directory 'data/working/tired_train/' created successfully.

# %%
images, labels = load_images_from_path('data/working/belly_pain_train', 0)

x += images
y += labels

images, labels = load_images_from_path('data/working/burping_train', 1)

x += images
y += labels

images, labels = load_images_from_path('data/working/discomfort_train', 2)

x += images
y += labels

images, labels = load_images_from_path('data/working/hungry_train', 3)

x += images
y += labels

images, labels = load_images_from_path('data/working/tired_train', 4)

x += images
y += labels

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

x_train_norm = np.array(x_train) / 255
x_test_norm = np.array(x_test) / 255

y_train_encoded = to_categorical(y_train) # hot encoding
y_test_encoded = to_categorical(y_test)

# %%
y_train_encoded[0] # Immagine che fa parte della categoria 3
# Out:
# array([0., 1., 0., 0., 0.])

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">⚙️ Model Training</span>

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
# <h3 align="left"><font color='#DEB887'>💡 Model Architecture:</font></h3>
#
# 1. **Input Layer**: Accepts input images of shape (224, 224, 3), which corresponds to images with a height and width of 224 pixels and three color channels (RGB).
# 2. **Resizing Layer: Resizes the input images to a smaller size of (64, 64). This reduction in image dimensions may help speed up training.
# 3. **Normalization Layer**: Normalizes pixel values to have zero mean and unit variance, which aids in stabilizing and speeding up the training process.
# 4. **Convolutional Layers**: Utilizes two convolutional layers:
#      - The first convolutional layer has 64 filters, a kernel size of 3x3, and ReLU activation.
#      - The second convolutional layer has 128 filters, a kernel size of 3x3, and ReLU activation.
# 7. **MaxPooling Layer**: Performs max pooling with a pool size of 2x2, reducing the spatial dimensions of the feature maps.
# 8. **Dropout Layer**: Introduces a dropout rate of 20% to prevent overfitting by randomly deactivating a fraction of neurons during training.
# 9. **Flatten Layer**: Flattens the 2D feature maps into a 1D vector to prepare for the fully connected layers.
# 10. **RandomFourierFeatures Layer**: Incorporates random Fourier features with 5 components, which can approximate non-linear mappings efficiently for the data.
# 11. **Compilation**: Compiles the model using the AdamW optimizer with a learning rate of 0.01, categorical cross-entropy loss function (suitable for multi-class classification), and accuracy as the evaluation metric.

# %%
import tensorflow as tf
import numpy as np

class RandomFourierFeatures(tf.keras.layers.Layer):
    def __init__(self, output_dim, scale=10.0):
        super(RandomFourierFeatures, self).__init__()
        self.output_dim = output_dim
        self.scale = scale

    def build(self, input_shape):
        input_dim = input_shape[-1]
        self.W = self.add_weight(
            shape=(input_dim, self.output_dim),
            initializer=tf.keras.initializers.RandomNormal(stddev=1.0 / self.scale),
            trainable=False,
        )
        self.b = self.add_weight(
            shape=(self.output_dim,),
            initializer=tf.keras.initializers.RandomUniform(0, 2 * np.pi),
            trainable=False,
        )

    def call(self, inputs):
        projection = tf.matmul(inputs, self.W) + self.b
        return tf.math.sqrt(2.0 / self.output_dim) * tf.math.cos(projection)

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,Flatten, Dense, Dropout,Normalization,Resizing,InputLayer
#from keras.layers import RandomFourierFeatures da levare
from keras.optimizers import Adam,Adafactor,AdamW,Lion
from keras.optimizers import Adadelta,Adagrad,Adamax,RMSprop,SGD,Nadam,Ftrl

model = Sequential()
model.add(InputLayer(input_shape=(224, 224, 3))) 
model.add(Resizing(64,64)) # Potrebbe essere tolto o diverso, lui vuole avere immagini più piccole
model.add(Normalization())
model.add(Conv2D(64, 3, strides=1, activation='relu'))
model.add(Conv2D(128, 3, strides=1, activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.2)) # 20% neuroni va scartato
model.add(Flatten()) # appiattiamo risultato ad una dimensione
#model.add(RandomFourierFeatures(5)) # Layer che fa un'approssimazione ----> QUESTO L'ABBIAMO RIMOSSO
model.add(Dense(5, activation='softmax'))  # ABBIAMO AGGIUNTO QUESTA
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])#AdamW removed and turnt into Adam
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resizing (Resizing)             │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalization (Normalization)   │ (None, 64, 64, 3)      │             7 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 62, 62, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 60, 60, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 5)              │       576,005 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 651,660 (2.49 MB)
#  Trainable params: 651,653 (2.49 MB)
#  Non-trainable params: 7 (32.00 B)

# %%
from keras.callbacks import ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy',
                              factor=0.5,
                              patience=2,
                              min_lr=0.006,
                              verbose=1)

hist = model.fit(x_train_norm, y_train_encoded, validation_data=(x_test_norm, y_test_encoded), epochs=10,callbacks=[reduce_lr])
# Out:
# Epoch 1/10
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 359ms/step - accuracy: 0.3997 - loss: 1.5856 - val_accuracy: 0.7507 - val_loss: 0.7789 - learning_rate: 0.0010
# Epoch 2/10
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 356ms/step - accuracy: 0.8456 - loss: 0.5202 - val_accuracy: 0.9265 - val_loss: 0.2447 - learning_rate: 0.0010
# Epoch 3/10
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 374ms/step - accuracy: 0.9661 - loss: 0.1319 - val_accuracy: 0.9711 - val_loss: 0.1252 - learning_rate: 0.0010
# Epoch 4/10
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 384ms/step - accuracy: 0.9861 - loss: 0.0484 - val_accuracy: 0.9738 - val_loss: 0.0872 - learning_rate: 0.0010
# Epoch 5/10
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 380ms/step - accuracy: 0.9957 - loss: 0.0209 - val_accuracy: 0.9790 - val_loss: 0.0742 - learning_rate: 0.0010
# Epoch 6/10
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 388ms/step - accuracy: 0.9970 - loss: 0.0228 - val_accuracy: 0.9790 - val_loss: 0.0880 - learning_rate: 0.0010
# Epoch 7/10
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 394ms/step - accuracy: 0.9995 - loss: 0.0085 - val_accuracy: 0.9764 - val_loss: 0.0785 - learning_rate: 0.0010
# Epoch 8/10
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9738 - val_loss: 0.0916 - learning_rate: 0.0010
# Epoch 9/10
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 447ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9843 - val_loss: 0.0668 - learning_rate: 0.0010
# Epoch 10/10
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 488ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9816 - val_loss: 0.0681 - learning_rate: 0.0010

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
plt.show()

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">🧪 Testing</span>

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#     &nbsp;<b>For predicting on single test files this code will be used. For each image file path obtained, the code performs the following operations:</b><br>
#     <br>
#     &nbsp;<b>- Loads the image using image.load_img() from the Keras preprocessing module, resizing it to the required dimensions of 224x224 pixels.</b><br>
#     &nbsp;<b>- Converts the image to a format compatible with the model for prediction (image.img_to_array() and np.expand_dims()).</b><br>
#     &nbsp;<b>- Utilizes the model for prediction on the image.</b><br>
#     &nbsp;<b>- Retrieves class labels corresponding to the categories ('belly pain', 'burping', 'discomfort', 'hungry', 'tired').</b><br>
#     &nbsp;<b>- Prints the original file path and its predicted category, appending this information to the results list.</b><br>
# </div>

# %%
import glob
import os

def get_png_files(directory):
    folders = ['belly_pain', 'burping', 'discomfort', 'hungry', 'tired'] 
    png_files = []

    for folder_name in folders:
        folder_path = os.path.join(directory, folder_name)
        if os.path.exists(folder_path):
            png_files.extend(glob.glob(os.path.join(folder_path, '*.png')))
        else:
            print(f"Folder '{folder_name}' does not exist in '{directory}'.")

    return png_files

directory_path = 'data/working/' 
png_files_list = get_png_files(directory_path)

results = []
for file_path in png_files_list:
    x = image.load_img(file_path, target_size=(224, 224))

    x = image.img_to_array(x)
    x = np.expand_dims(x, axis=0)

    y = model.predict(x)

    class_labels = ['belly pain','burping','discomfort','hungry','tired']

    # for i, label in enumerate(class_labels):
    #     print(f'{label}: {y[0][i]}')

    results.append(f"Original:{file_path.split('/')[2]} Predicted: {class_labels[np.argmax(y)]}")
    
print('\n')

for i in results:
    print(i)
    print('\n')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
#
# Original:belly_pain Predicted: belly pain
#
#
# Original:burping Predicted: burping
#
#
# Original:discomfort Predicted: discomfort
#
#
# Original:hungry Predicted: hungry
#
#
# Original:tired Predicted: tired

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Predict on the test set
y_pred_probs = model.predict(x_test_norm)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test_encoded, axis=1)

# Compute confusion matrix with all class labels
class_labels = ['belly pain', 'burping', 'discomfort', 'hungry', 'tired']
cm = confusion_matrix(y_true, y_pred, labels=[0, 1, 2, 3, 4])

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step
